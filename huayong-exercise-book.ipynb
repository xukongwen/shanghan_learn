# %%
from shlib import ShangHanLun
sh = ShangHanLun()
sh.load_decoction_data('data/SH_ty2.json')
# sh.decoction_dataframe

# %%
sh.show_decoction_wx_trend("桂枝汤")
# Out:
# {'桂枝': '3两', '芍药': '3两', '炙甘草': '2两', '生姜': '3两', '大枣': '12枚'}
# {'桂枝': 46.875, '芍药': 46.875, '炙甘草': 31.25, '生姜': 46.875, '大枣': 36.0}
# {'木': 93.75, '金': 46.875, '土': 67.25}

# %%
sh.show_wx_trend()

# %%
sh.show_wx_trend_by_medicine_count()

# %%
sh.show_six_channel_wx_trend()

# %%
sh.show_six_channel_wx_trend_by_medicine_count()
# Out:
# {'厥阴': {'土': 22, '无': 13, '木': 26, '水': 6, '火': 10, '金': 8}, '太阳': {'土': 115, '无': 26, '木': 115, '水': 35, '火': 41, '金': 56}, '太阴': {'土': 6, '木': 6, '火': 1, '金': 3}, '少阳': {'土': 2, '木': 2, '火': 1, '金': 1}, '少阴': {'土': 16, '无': 7, '木': 21, '水': 6, '火': 8, '金': 8}, '阳明': {'土': 17, '无': 12, '木': 14, '水': 10, '火': 14, '金': 11}, '阴阳': {'土': 9, '无': 1, '木': 6, '水': 3, '火': 2, '金': 5}, '霍乱': {'土': 9, '无': 1, '木': 10, '水': 3, '火': 1, '金': 1}}
