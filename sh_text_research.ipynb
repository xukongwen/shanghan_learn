# %%
from shlib.shtext import ShangHanLunText
sht = ShangHanLunText()
sht.load_text("data/SH_text.json")
# Out:
#        six_channel                                               text
# number
# 1               太阳                                  太阳之为病。脉浮。头项强痛而恶寒。
# 2               太阳                             太阳病。发热。汗出。恶风。脉缓者。名为中风。
# 3               太阳               太阳病。或已发热。或未发热。必恶寒。体痛。呕逆。脉阴阳俱紧者。名为伤寒。
# 4               太阳               伤寒一日。太阳受之。脉若静者。为不传。颇欲吐。若躁烦。脉数急者。为传也。
# 5               太阳                              伤寒二三日。阳明、少阳证不见者。为不传也。
# 6               太阳  太阳病。发热而渴。不恶寒者。为温病。若发汗已。身灼热者。名风温。风温为病。脉阴阳俱浮。自汗出...
# 7               太阳  病有发热恶寒者。发于阳也。无热恶寒者。发于阴也。发于阳七日愈。发于阴六日愈。以阳数七 、阴数...
# 8               太阳        太阳病。头痛。至七日以上自愈者。以行其经尽故也。若欲作再经者。针足阳明。使经不传则愈。
# 9               太阳                                     太阳病。欲解时。从巳至未上。
# 10              太阳                                   风家。表解而不了了者。十二日愈。
# 11              太阳      病人身大热。反欲得衣者。热在皮肤。寒在骨髓也。身大寒。反不欲近衣者。寒在皮肤。热在骨髓也。
# 12              太阳  太阳中风。阳浮而阴弱。阳浮者。热自发。阴弱者。汗自出。啬啬恶寒。淅淅恶风。翕翕发热。鼻鸣干呕...
# ...

# %%
# 查词
sht.search_word("恶风")
# Out:
# 序号： 2
# 六经： 太阳
# 原文： 太阳病。发热。汗出。恶风。脉缓者。名为中风。
#
# 序号： 12
# 六经： 太阳
# 原文： 太阳中风。阳浮而阴弱。阳浮者。热自发。阴弱者。汗自出。啬啬恶寒。淅淅恶风。翕翕发热。鼻鸣干呕者。桂枝汤主之。
#
# 序号： 13
# 六经： 太阳
# 原文： 太阳病。头痛。发热。汗出。恶风。桂枝汤主之。
#
# 序号： 14
# 六经： 太阳
# 原文： 太阳病。项背强几几。反汗出。恶风者。桂枝加葛根汤主之。
#
# 序号： 20
# 六经： 太阳
# 原文： 太阳病。发汗。遂漏不止。其人恶风。小便难。四肢微急。难以屈伸者。桂枝加附子汤主之。
#
# 序号： 31
# 六经： 太阳
# 原文： 太阳病。项背强几几。无汗。恶风。葛根汤主之。
#
# 序号： 35
# 六经： 太阳
# 原文： 太阳病。头痛。发热。身疼。腰痛。骨节疼痛。恶风。无汗而喘者。麻黄汤主之。
#
# 序号： 38
# 六经： 太阳
# 原文： 太阳中风。脉浮紧。发热。恶寒。身疼痛。不汗出而烦躁者。大青龙汤主之。若脉微弱。汗出。恶风者。不可服 之。服之则厥逆。筋惕肉瞤。此为逆也。
#
# 序号： 98
# 六经： 太阳
# 原文： 得病六七日。脉迟浮弱。恶风寒。手足温。医二三下之。不能食。而胁下满痛。面目及身黄。颈项强。小便难者。 与柴胡汤。后必下重。本渴。饮水而呕者。柴胡汤不中与也。食谷者哕。
#
# 序号： 99
# 六经： 太阳
# 原文： 伤寒四五日。身热。恶风。颈项强。胁下满。手足温而渴者。小柴胡汤主之。
#
# 序号： 110
# 六经： 太阳
# 原文： 太阳病二日。反躁。凡熨其背而大汗出。大热入胃。胃中水竭。躁烦。必发讝语。 十余日。振慄自下利者。此为欲解也。故其汗从腰以下不得汗。欲小便不得。反呕。欲失溲。足下恶风。大便鞕 。小 便当数。而反不数及不多。大便已。头卓然而痛。其人足心必热。谷气下流故也。
#
# 序号： 168
# 六经： 太阳
# 原文： 伤寒。若吐若下后。七八日不解。热结在里。表里俱热。时时恶风。大渴。舌上干燥而烦。欲饮水数升者。白虎 加人参汤主之。
#
# 序号： 175
# 六经： 太阳
# 原文： 风湿相搏。骨节疼烦。掣痛不得屈伸。近之则痛剧。汗出。短气。小便不利。恶风。不欲去衣。或身微肿者。甘 草附子汤主之。

# %%
# 关键词统计
sht.count_word("发汗")
# Out:
# 关键词 '发汗' 累计出现 85 次，其中：
# 太阳：60 次
# 阳明：16 次
# 少阳：3 次
# 太阴：1 次
# 少阴：4 次
# 厥阴：0 次
# 霍乱：1 次
# 阴阳：0 次

# %%
pd.Series([1,2], index=list('aa'))
# Out:
# a    1
# a    2
# dtype: int64
